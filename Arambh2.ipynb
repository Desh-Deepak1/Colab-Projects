# %% [markdown]
# <a href="https://colab.research.google.com/github/Desh-Deepak1/Colab-Projects/blob/main/Arambh2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **FUNCTIONS**

# %%
# input , logic , out put

# %% [markdown]
# # **1. Defining a Function**

# %%
def hello():
  print("Hello World")

# %% [markdown]
# **2 .CALLING FUNCTION**

# %%
hello()
# Out:
# Hello World

# %% [markdown]
# ## **3. Function With parameter**

# %%
def hello(name):
  print(f"Hello {name}")

# %%
hello("Deepak")
# Out:
# Hello Deepak

# %% [markdown]
# ## **F String**

# %%
# "string"
# f"String { Passed parrameter}"

# %%
# Example
country = "India"
capital = "New Delhi"
print(f"{capital} is the capital of {country}")
# Out:
# New Delhi is the capital of India

# %%
def Add_number(num1 , num2):
  c = int(num1) + int(num2)
  return c

# %%
a = i5nt(input("Enter First Number : "))
b = int(input("Enter Second Number : "))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-463/4260346135.py in <cell line: 0>()
# ----> 1 a = i5nt(input("Enter First Number : "))
#       2 b = int(input("Enter Second Number : "))
#
# NameError: name 'i5nt' is not defined

# %%
Add_number(a,b)

# %% [markdown]
# ## **5 . Default Parametres**

# %%
def hello(name ="Guest"):
  print(f"Hello {name}")

# %%
hello()

# %% [markdown]
# # **6 . Keyword Arguments**

# %%
def add_numbers(x=10 , y=45):
  return x+y

# %%
add_numbers()
# Out:
# 55

# %% [markdown]
# ## **7 . Scop and Global Variable**

# %%
def test(x=10):
  print(x)

# %%
test()
# Out:
# 10

# %%
test(11)
# Out:
# 11

# %%
# Global Variable = Defined Out side the function
x = 100
def test():
  print(x)

# %%
test()
# Out:
# 100

# %%
n = 23
def test(n):
  n=21
  print(n)

# %%
test(19)
# Out:
# 21

# %% [markdown]
# ### **8 . Nested function**

# %%
def hello(name):
  print(f"hello {name}")
def fav_city(city,name):
  hello(name)
  print(f"Wellcome to {city}")

# %%
fav_city("Prayragraj", "Deepak")
# Out:
# hello Deepak
# Wellcome to Prayragraj

# %% [markdown]
# # **9 . ERROR HANDILING IN PYTHON**

# %%
print("Hello World"
# Out:
#   File "/tmp/ipython-input-463/353226650.py", line 1
#     print("Hello World"
#                        ^
# SyntaxError: incomplete input

# %%
print("Hello World")
# Out:
# Hello World

# %%
2+ "hello"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-463/497911435.py in <cell line: 0>()
# ----> 1 2+ "hello"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-463/3474671970.py in <cell line: 0>()
# ----> 1 name
#
# NameError: name 'name' is not defined

# %%
name = "deepak"

# %%
ls = [1,2,3]

# %%
ls[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-463/2418266200.py in <cell line: 0>()
# ----> 1 ls[3]
#
# IndexError: list index out of range

# %%
ls[2]
# Out:
# 3

# %%
d1 ={'k1': 'v1'}

# %%
d1['k2']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-463/3104928067.py in <cell line: 0>()
# ----> 1 d1['k2']
#
# KeyError: 'k2'

# %%
d1['k1']
# Out:
# 'v1'

# %%
int("Hello")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-463/45454751.py in <cell line: 0>()
# ----> 1 int("Hello")
#
# TypeError: 'str' object is not callable

# %%
int(2.5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-463/1108737373.py in <cell line: 0>()
# ----> 1 int(2.5)
#
# TypeError: 'str' object is not callable

# %%
# try except

try:
  result =10/0
except ZeroDivisionError:
  print("You can't divide by zero")
else:
  print(result)
# Out:
# You can't divide by zero

# %% [markdown]
# ## **10 . FILE HANDLING IN PYTHON**

# %%
file_name = "myfile.txt"
content = "This is a sample text file created in Colab."

with open(file_name, 'w') as file:
  file.write(content)

print(f"File '{file_name}' created successfully.")
# Out:
# File 'myfile.txt' created successfully.

# %%
with open(file_name, 'r') as file:
  file_content = file.read()

# %%
from os import write
with open(file_name ,'a') as f:
  f.write('\n New Line')

# %%
with open(file_name , 'r') as f:
  print(f.read())
# Out:
#  New Line

# %%
import csv

file_name = "my_data.csv"

# Define header and rows
header = ["Column1", "Column2"]
data = [
    ["Value1A", "Value1B"],
    ["Value2A", "Value2B"]
]

# Write to CSV file
with open(file_name, 'w', newline='') as csvfile:
    csv_writer = csv.writer(csvfile)
    csv_writer.writerow(header)
    csv_writer.writerows(data)

print(f"CSV file '{file_name}' created successfully with two columns and two rows.")
# Out:
# CSV file 'my_data.csv' created successfully with two columns and two rows.
