# %% [markdown]
# <a href="https://colab.research.google.com/github/Desh-Deepak1/Colab-Projects/blob/main/NumpyPandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **NUMPY**

# %%
import numpy as np

# %%
arr = np.array([1,2,3,4,5])

# %%
arr1 = np.array([1,2,3])

# %%
arr2 = np.array([6,7,8])

# %%
arr1 + arr2
# Out:
# array([ 7,  9, 11])

# %%
arr3 =np.array([1,2,3,4,5 , 6])

# %%
arr3[-2]
# Out:
# np.int64(5)

# %%
arr3[1:3]
# Out:
# array([2, 3])

# %%
arr3.shape
# Out:
# (6,)

# %%
arr3.reshape(2,3)
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr3 + 1
# Out:
# array([2, 3, 4, 5, 6, 7])

# %%
arr3 *2
# Out:
# array([ 2,  4,  6,  8, 10, 12])

# %%
m1 = np.array([[1,2], [3,4]])
m2 = np.array([[5,6],[7,8]])

# %%
np.dot(m1 ,m2)
# Out:
# array([[19, 22],
#        [43, 50]])

# %%
np.mean(arr3)
# Out:
# np.float64(3.5)

# %%
np.max(arr3)
# Out:
# np.int64(6)

# %%
np.std(arr3)
# Out:
# np.float64(1.707825127659933)

# %%
np.random.rand(5)
# Out:
# array([0.09357086, 0.49154702, 0.35323386, 0.14230194, 0.33542001])

# %%
np.random.randint(1000,9999)
# Out:
# 2602

# %%
arr =[1,2,3,np.nan, 4 ,5 ,6]

# %%
arr
# Out:
# [1, 2, 3, nan, 4, 5, 6]

# %%
np.isnan(arr)
# Out:
# array([False, False, False,  True, False, False, False])

# %%
import time

# %%
L1 = list(range(100000000))
start =time.time()
sum(L1)
end = time.time()
print(end-start)
# Out:
# 0.7837550640106201

# %%
start =time.time()
np.sum(L1)
end = time.time()
print(end-start)
# Out:
# 4.550435543060303

# %% [markdown]
# # **PANDAS**

# %%
import pandas as pd

# %%
# People :p1 , p2 , p3
# Age : 20,30,40

# %%
d = { 'People':['p1','p2','p3'], 'Age':[20,30,40]}

# %%
df =pd.DataFrame(d)

# %%
df
# Out:
#   People  Age
# 0     p1   20
# 1     p2   30
# 2     p3   40

# %%
pd.read_excel("student_dataset.xlsx")
# Out:
#    Student ID     Name Gender  Age  Math  Science  English  History
# 0        S001    Alice      F   14    85       92       78       88
# 1        S002      Bob      M   15    62       55       70       60
# 2        S003  Charlie      M   14    95       88       91       93
# 3        S004    Diana      F   15    74       70       82       77
# 4        S005    Ethan      M   14    45       50       55       48
# 5        S006    Fiona      F   15    90       94       88       91
# 6        S007   George      M   14    68       72       65       70
# 7        S008   Hannah      F   15    81       85       90       83
# 8        S009      Ian      M   14    77       65       72       68
# 9        S010    Julia      F   15    55       60       58       62
# 10       S011    Kevin      M   14    92       90       85       87
# 11       S012    Laura      F   15    60       58       63       55
# 12       S013     Mike      M   14    88       82       80       85
# ...

# %%
df
# Out:
#   People  Age
# 0     p1   20
# 1     p2   30
# 2     p3   40

# %%
df.to_csv("sample.CSV")

# %%
pd.read_csv("sample.CSV")
# Out:
#    Unnamed: 0 People  Age
# 0           0     p1   20
# 1           1     p2   30
# 2           2     p3   40

# %%
df.to_csv("sample.CSV", index = False)

# %%
pd.read_csv("sample.CSV")
# Out:
#   People  Age
# 0     p1   20
# 1     p2   30
# 2     p3   40
