# %% [markdown]
# <a href="https://colab.research.google.com/github/Desh-Deepak1/Colab-Projects/blob/main/Arambh3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1 . CREATING A DICTIONARY**

# %%
# List - [,]
# Dict - {Key :value}
# Tuple (,)
# set {,}

# %%
#Dict - Key Value Pair

# %%
student ={ "name": "Deepak", "Age": 20, "Gender": "Male"}
# key & value are linked using :

# %%
print(student)
# Out:
# {'name': 'Deepak', 'Age': 20, 'Gender': 'Male'}

# %% [markdown]
# # **2. Accessing Value**

# %%
student["Age"]
# Out:
# 20

# %%
student["name"]
# Out:
# 'Deepak'

# %%
student
# Out:
# {'name': 'Deepak', 'Age': 20, 'Gender': 'Male'}

# %%
student["name"]= "Desh Deepak"

# %%
student
# Out:
# {'name': 'Desh Deepak', 'Age': 20, 'Gender': 'Male'}

# %% [markdown]
# # **3. Loop Through a Dictionary**

# %%
student
# Out:
# {'name': 'Desh Deepak', 'Age': 20, 'Gender': 'Male'}

# %%
for key in student:
  print(key)
# Out:
# name
# Age
# Gender

# %%
for value in student.values():
  print(value)
# Out:
# Desh Deepak
# 20
# Male

# %%
for k , v in student.items():
  print(k,v)
# Out:
# name Desh Deepak
# Age 20
# Gender Male

# %%
for k in student:
  if k=="name":
    print("found the Key")
# Out:
# found the Key

# %%
if "name" in student:
  print(True)
else:
  print(False)
# Out:
# True

# %% [markdown]
# # **Tuple**

# %% [markdown]
# # **4 . Creating a tuple** **bold text**

# %%
t1 =(1,2 ,23,4)

# %%
t1
# Out:
# (1, 2, 23, 4)

# %% [markdown]
# # **5. Accessing Elements**

# %%
t1[2]
# Out:
# 23

# %%
t1[0]
# Out:
# 1

# %%
t1[1]
# Out:
# 2

# %% [markdown]
# ## **6. Tuple Operation**

# %%
t2 =("a","b","c")

# %%
t1+t2
# Out:
# (1, 2, 23, 4, 'a', 'b', 'c')

# %%
t1*3
# Out:
# (1, 2, 23, 4, 1, 2, 23, 4, 1, 2, 23, 4)

# %% [markdown]
# # **7. Tuple Unpacking**

# %%
t1 =(1,2,3)

# %%
a=1
b=2
c=3

# %%
a,b,c=10,20,3

# %%
a
# Out:
# 10

# %%
b
# Out:
# 20

# %% [markdown]
# ## **LIST VS TUPLE**

# %%
# List  - Mutable(Add , Remove , Modify)
# Tuple - Immitable(Can't Add , can't remove ....)
# List - Memory High
# Tuple - Memory Low

# %% [markdown]
# ## **8.Sets**

# %%
L1 =[1,2,3]

# %%
# unique Value in list

s1=set(L1)

# %%
s1
# Out:
# {1, 2, 3}

# %%
s2 = {2,5,6,7}

# %% [markdown]
# ## **9.Set oprations**

# %%
s1.union(s2)
# Out:
# {1, 2, 3, 5, 6, 7}

# %%
s1.intersection(s2)
# Out:
# {2}

# %%
s1.difference(s2)
# Out:
# {1, 3}
