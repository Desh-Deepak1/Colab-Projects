# %% [markdown]
# <a href="https://colab.research.google.com/github/Desh-Deepak1/Colab-Projects/blob/main/Arambh4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PYHTHON MODULES**

# %%
# math , random
# Python Library / Python Module

# %%
import math

# %%
math.sqrt(100)
# Out:
# 10.0

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.pow(2,10)
# Out:
# 1024.0

# %%
math.factorial(5)
# Out:
# 120

# %%
import math as m

# %%
m.pow(2,6)
# Out:
# 64.0

# %%
import random

# %%
random.random()
# Out:
# 0.03681368527929618

# %%
random.randint(1,1000)
# Out:
# 350

# %%
# Use like Generate 4 digit OTP It gives random numbe of 4 digit evrey time

random.randint(1000,9999)
# Out:
# 8567

# %%
L1 =["Black" , "White" , "Red" , "Green" , "yellow"]

# %%
random.choice(L1)
# Out:
# 'Red'

# %%
random.shuffle(L1)

# %%
L1
# Out:
# ['Black', 'Green', 'Red', 'yellow', 'White']

# %%
L2 =["c1","c2","c3", "c5", "c4"]

# %%
random.shuffle(L2)

# %%
L2
# Out:
# ['c5', 'c4', 'c1', 'c3', 'c2']

# %%
# Libraries - os , json , requests

# %% [markdown]
# ## **PYTHON MODULE - Datetime**

# %%
import datetime

# %%
from datetime import datetime , date , time , timedelta

# %%
current_datetime = datetime.now()

# %%
current_datetime
# Out:
# datetime.datetime(2026, 3, 3, 6, 10, 42, 698937)

# %%
current_datetime.year
# Out:
# 2026

# %%
current_datetime.date
# Out:
# <function datetime.date>

# %%
current_datetime.month
# Out:
# 3

# %%
current_datetime.day
# Out:
# 3

# %%
#3rd March 2026
# 03-03-2026
# 03/-3/2026

# Python Standard convenction
# Y-M-D
date(2026,3,3)
# Out:
# datetime.date(2026, 3, 3)

# %%
# Python Standard convenction  Time
# HH:MM:SS
time(11,47,45)
# Out:
# datetime.time(11, 47, 45)

# %%
# Y - M -D -HH - MM - SS
datetime(2026,3,3,11,50,32)
# Out:
# datetime.datetime(2026, 3, 3, 11, 50, 32)

# %%
from datetime import timedelta

# %%
timedelta(hours=5)
# Out:
# datetime.timedelta(seconds=18000)

# %%
current_datetime + timedelta(hours=5)
# Out:
# datetime.datetime(2026, 3, 3, 11, 10, 42, 698937)

# %%
# sort date - 3rd march 2026
