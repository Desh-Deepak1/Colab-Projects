# %% [markdown]
# <a href="https://colab.research.google.com/github/Desh-Deepak1/Colab-Projects/blob/main/Python_Libaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ----Data Science----
# Numpy , Pandas , Matplotlib
# Sklearn , Pytorch , Tensorflow

#---APIs---
#Requests ,Flask ,FastAPI

#----Web Development----
# Flask , Stremlit , Django

#----Web Scraping / Web Crawling---
# Selenium , Beautifulsoup , Scrapy

#----ComputerVision / Image Processing ----
#OpenCV , Pillow , MoviePy , Ultralytics

# %% [markdown]
# # **PYTHON RESOURCES**

# %%
# -----Reading-----
# W3School
# GeeksforGeeks
# TutorialsPoint

#----Testing---
# Hackerrank
# LeetCode
# CodeChef

#--YouTube--
# TheNewBoston
